# %% [markdown]
# ## Install dependencies

# %%
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/240.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/240.9 kB ? eta -:--:--
#      ------ ------------------------------ 41.0/240.9 kB 393.8 kB/s eta 0:00:01
#      ----------- ------------------------- 71.7/240.9 kB 563.7 kB/s eta 0:00:01
#      ------------------ ----------------- 122.9/240.9 kB 654.9 kB/s eta 0:00:01
#      ---------------------- ------------- 153.6/240.9 kB 654.6 kB/s eta 0:00:01
#      ------------------------------ ----- 204.8/240.9 kB 731.4 kB/s eta 0:00:01
#      ------------------------------------ 240.9/240.9 kB 739.2 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/172.0 kB ? eta -:--:--
#      --------- ----------------------------- 41.0/172.0 kB 1.9 MB/s eta 0:00:01
#      ------------------ -------------------- 81.9/172.0 kB 1.5 MB/s eta 0:00:01
# ...

# %% [markdown]
# ## Bring market watch data

# %%
import gym
import gym_anytrading

from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import A2C

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import gym
# ----> 2 import gym_anytrading
#       4 from stable_baselines.common.vec_env import DummyVecEnv
#       5 from stable_baselines import A2C
#
# ModuleNotFoundError: No module named 'gym_anytrading'
